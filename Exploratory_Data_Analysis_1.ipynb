# %% [markdown]
# <a href="https://colab.research.google.com/github/miraqulass/MachineLearning/blob/MLPractices/Exploratory_Data_Analysis_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/ProjectRound2/
# Out:
# /content/drive/MyDrive/ProjectRound2

# %%
import pandas as pd

# %%
sensor_data = pd.read_csv('sensor_data.csv')

# %%
sensor_data.head()
# Out:
#    Time  Temperature      Speed  EngineKnock  CoolantTemp  ThrottlePosition  \
# 0     0    91.843427  25.610070            5    86.328561         17.574481
# 1     1    87.583211  23.838311            4    88.955467         83.487135
# 2     2    89.652564  60.784985            2    91.970542         73.540258
# 3     3    89.766499  67.430460            8    89.902989         70.925938
# 4     4    89.656260  43.729523            5    94.771793         39.279315
#
#     MAPSensor  OxygenSensor  RainSensor  VoltageSensor  CamshaftPosition
# 0  106.017942      1.760350    0.553435      11.257727        359.248433
# 1  116.985419      1.121733   -3.608120       8.319433        359.837321
# 2  106.844004     -0.341119   -2.623565      14.938086          3.299724
# 3  110.287983     -1.938978   -2.259057      14.739458          9.230130
# 4   96.269690      0.741096   -1.554332       9.693600          6.116035

# %%
sensor_data['VehicleID'] = range(1, len(sensor_data) + 1)

# %%
sensor_data
# Out:
#         Time  Temperature      Speed  EngineKnock  CoolantTemp  \
# 0          0    91.843427  25.610070            5    86.328561
# 1          1    87.583211  23.838311            4    88.955467
# 2          2    89.652564  60.784985            2    91.970542
# 3          3    89.766499  67.430460            8    89.902989
# 4          4    89.656260  43.729523            5    94.771793
# ...      ...          ...        ...          ...          ...
# 99995  99995    90.608574  23.592977            5    87.597933
# 99996  99996    90.132754  54.061467            6    90.950251
# 99997  99997    92.519117  41.213714            9    86.317906
# 99998  99998    89.670646  35.996885            4    88.132446
# 99999  99999    88.624700  61.634277            0    90.282581
#
#        ThrottlePosition   MAPSensor  OxygenSensor  RainSensor  VoltageSensor  \
# 0             17.574481  106.017942      1.760350    0.553435      11.257727
# ...

# %%
sensor_data = sensor_data[['VehicleID'] + [col for col in sensor_data.columns if col != 'VehicleID']]

# %%
sensor_data
# Out:
#        VehicleID   Time  Temperature      Speed  EngineKnock  CoolantTemp  \
# 0              1      0    91.843427  25.610070            5    86.328561
# 1              2      1    87.583211  23.838311            4    88.955467
# 2              3      2    89.652564  60.784985            2    91.970542
# 3              4      3    89.766499  67.430460            8    89.902989
# 4              5      4    89.656260  43.729523            5    94.771793
# ...          ...    ...          ...        ...          ...          ...
# 99995      99996  99995    90.608574  23.592977            5    87.597933
# 99996      99997  99996    90.132754  54.061467            6    90.950251
# 99997      99998  99997    92.519117  41.213714            9    86.317906
# 99998      99999  99998    89.670646  35.996885            4    88.132446
# 99999     100000  99999    88.624700  61.634277            0    90.282581
#
#        ThrottlePosition   MAPSensor  OxygenSensor  RainSensor  VoltageSensor  \
# ...

# %%
telematics_data = pd.read_csv('telematics_data_random_route.csv')

# %%
telematics_data.head()
# Out:
#    Time                     GPS  Speed(km/hr)  Acceleration
# 0     0  (-1.286389, 36.817223)           5.0      0.000000
# 1     1     (1.6681, 37.676039)           0.0     -5.000000
# 2     2   (3.163127, 39.054601)           0.0     -1.318793
# 3     3   (1.864821, 37.579328)           0.0     -2.185179
# 4     4   (3.951431, 39.826724)           0.0     -0.834398

# %%
telematics_data['VehicleID'] = range(1, len(telematics_data) + 1)

# %%
telematics_data
# Out:
#         Time                       GPS  Speed(km/hr)  Acceleration  VehicleID
# 0          0    (-1.286389, 36.817223)      5.000000      0.000000          1
# 1          1       (1.6681, 37.676039)      0.000000     -5.000000          2
# 2          2     (3.163127, 39.054601)      0.000000     -1.318793          3
# 3          3     (1.864821, 37.579328)      0.000000     -2.185179          4
# 4          4     (3.951431, 39.826724)      0.000000     -0.834398          5
# ...      ...                       ...           ...           ...        ...
# 99995  99995    (-78.658253, 1.383327)     88.826384      1.920252      99996
# 99996  99996    (-0.437352, 38.841951)     89.383227      0.556843      99997
# 99997  99997  (-30.972015, -39.863121)     87.624982     -1.758245      99998
# 99998  99998      (0.84699, 45.106829)     87.784149      0.159167      99999
# 99999  99999  (-24.034652, -44.049345)     89.571981      1.787831     100000
#
# [100000 rows x 5 columns]

# %%
telematics_data = telematics_data[['VehicleID'] + [col for col in telematics_data.columns if col != 'VehicleID']]

# %%
telematics_data
# Out:
#        VehicleID   Time                       GPS  Speed(km/hr)  Acceleration
# 0              1      0    (-1.286389, 36.817223)      5.000000      0.000000
# 1              2      1       (1.6681, 37.676039)      0.000000     -5.000000
# 2              3      2     (3.163127, 39.054601)      0.000000     -1.318793
# 3              4      3     (1.864821, 37.579328)      0.000000     -2.185179
# 4              5      4     (3.951431, 39.826724)      0.000000     -0.834398
# ...          ...    ...                       ...           ...           ...
# 99995      99996  99995    (-78.658253, 1.383327)     88.826384      1.920252
# 99996      99997  99996    (-0.437352, 38.841951)     89.383227      0.556843
# 99997      99998  99997  (-30.972015, -39.863121)     87.624982     -1.758245
# 99998      99999  99998      (0.84699, 45.106829)     87.784149      0.159167
# 99999     100000  99999  (-24.034652, -44.049345)     89.571981      1.787831
#
# [100000 rows x 5 columns]

# %%
combined_data = pd.merge(sensor_data, telematics_data, on='VehicleID', how='inner')

# %%
combined_data
# Out:
#        VehicleID  Time_x  Temperature      Speed  EngineKnock  CoolantTemp  \
# 0              1       0    91.843427  25.610070            5    86.328561
# 1              2       1    87.583211  23.838311            4    88.955467
# 2              3       2    89.652564  60.784985            2    91.970542
# 3              4       3    89.766499  67.430460            8    89.902989
# 4              5       4    89.656260  43.729523            5    94.771793
# ...          ...     ...          ...        ...          ...          ...
# 99995      99996   99995    90.608574  23.592977            5    87.597933
# 99996      99997   99996    90.132754  54.061467            6    90.950251
# 99997      99998   99997    92.519117  41.213714            9    86.317906
# 99998      99999   99998    89.670646  35.996885            4    88.132446
# 99999     100000   99999    88.624700  61.634277            0    90.282581
#
# ...

# %%
maintenance_data = pd.read_csv('maintenance_data.csv')

# %%
maintenance_data.head()
# Out:
#    VehicleID            Timestamp         MaintenanceType  \
# 0          1  2023-07-01 07:21:28              Oil Change
# 1          1  2023-07-01 07:21:28       Brake Replacement
# 2          1  2023-07-01 07:21:28  Air Filter Replacement
# 3          1  2023-07-01 07:21:28           Tire Rotation
# 4          2  2023-02-27 18:48:36       Brake Replacement
#
#    MaintenanceCategory MaintenanceFrequency MaintenanceSeverity  \
# 0  Routine Maintenance       Every 3 months            Moderate
# 1              Repairs            As needed                High
# 2            Schedules       Every 6 months                 Low
# 3  Routine Maintenance       Every 3 months            Moderate
# 4              Repairs            As needed                High
#
#            MaintenanceDate  MaintenanceCost(Ksh) MaintenanceInterval  \
# 0  2023-03-30 04:31:56.976              31767.44            108 days
# 1  2023-10-27 22:04:20.976              39212.76            345 days
# ...

# %%
combined_data = pd.merge(combined_data, maintenance_data, on='VehicleID', how='inner')

# %%
combined_data.head()
# Out:
#    VehicleID  Time_x  Temperature      Speed  EngineKnock  CoolantTemp  \
# 0          1       0    91.843427  25.610070            5    86.328561
# 1          1       0    91.843427  25.610070            5    86.328561
# 2          1       0    91.843427  25.610070            5    86.328561
# 3          1       0    91.843427  25.610070            5    86.328561
# 4          2       1    87.583211  23.838311            4    88.955467
#
#    ThrottlePosition   MAPSensor  OxygenSensor  RainSensor  ...  Acceleration  \
# 0         17.574481  106.017942      1.760350    0.553435  ...           0.0
# 1         17.574481  106.017942      1.760350    0.553435  ...           0.0
# 2         17.574481  106.017942      1.760350    0.553435  ...           0.0
# 3         17.574481  106.017942      1.760350    0.553435  ...           0.0
# 4         83.487135  116.985419      1.121733   -3.608120  ...          -5.0
#
#              Timestamp         MaintenanceType  MaintenanceCategory  \
# ...

# %%
combined_data.describe().T
# Out:
#                          count           mean           std          min  \
# VehicleID             400000.0   50000.500000  28867.549542     1.000000
# Time_x                400000.0   49999.500000  28867.549542     0.000000
# Temperature           400000.0      90.002591      2.118191    80.271264
# Speed                 400000.0      44.974537     14.429944    20.000278
# EngineKnock           400000.0       5.007410      2.245335     0.000000
# CoolantTemp           400000.0      89.998911      2.125706    80.102124
# ThrottlePosition      400000.0      49.891848     28.911087     0.000852
# MAPSensor             400000.0     100.022866     11.550234    80.000073
# OxygenSensor          400000.0       0.203134      2.004628    -8.619409
# RainSensor            400000.0       0.489547      2.022806    -7.989643
# VoltageSensor         400000.0      12.001475      1.998965     4.124959
# CamshaftPosition      400000.0     179.892374    103.888317     0.006950
# ...

# %%
combined_data = combined_data.drop(['Time_x', 'Time_y'], axis=1)

# %%
combined_data.head(20)
# Out:
#     VehicleID  Temperature      Speed  EngineKnock  CoolantTemp  \
# 0           1    91.843427  25.610070            5    86.328561
# 1           1    91.843427  25.610070            5    86.328561
# 2           1    91.843427  25.610070            5    86.328561
# 3           1    91.843427  25.610070            5    86.328561
# 4           2    87.583211  23.838311            4    88.955467
# 5           2    87.583211  23.838311            4    88.955467
# 6           2    87.583211  23.838311            4    88.955467
# 7           2    87.583211  23.838311            4    88.955467
# 8           3    89.652564  60.784985            2    91.970542
# 9           3    89.652564  60.784985            2    91.970542
# 10          3    89.652564  60.784985            2    91.970542
# 11          3    89.652564  60.784985            2    91.970542
# 12          4    89.766499  67.430460            8    89.902989
# 13          4    89.766499  67.430460            8    89.902989
# ...

# %%
col = combined_data.pop('Timestamp')
combined_data.insert(1, col.name, col)

# %%
combined_data
# Out:
#         VehicleID            Timestamp  Temperature      Speed  EngineKnock  \
# 0               1  2023-07-01 07:21:28    91.843427  25.610070            5
# 1               1  2023-07-01 07:21:28    91.843427  25.610070            5
# 2               1  2023-07-01 07:21:28    91.843427  25.610070            5
# 3               1  2023-07-01 07:21:28    91.843427  25.610070            5
# 4               2  2023-02-27 18:48:36    87.583211  23.838311            4
# ...           ...                  ...          ...        ...          ...
# 399995      99999  2023-10-02 18:10:12    89.670646  35.996885            4
# 399996     100000  2023-07-21 05:09:15    88.624700  61.634277            0
# 399997     100000  2023-07-21 05:09:15    88.624700  61.634277            0
# 399998     100000  2023-07-21 05:09:15    88.624700  61.634277            0
# 399999     100000  2023-07-21 05:09:15    88.624700  61.634277            0
#
# ...

# %%
combined_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 400000 entries, 0 to 399999
# Data columns (total 23 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   VehicleID             400000 non-null  int64
#  1   Timestamp             400000 non-null  object
#  2   Temperature           400000 non-null  float64
#  3   Speed                 400000 non-null  float64
#  4   EngineKnock           400000 non-null  int64
#  5   CoolantTemp           400000 non-null  float64
#  6   ThrottlePosition      400000 non-null  float64
#  7   MAPSensor             400000 non-null  float64
#  8   OxygenSensor          400000 non-null  float64
#  9   RainSensor            400000 non-null  float64
#  10  VoltageSensor         400000 non-null  float64
#  11  CamshaftPosition      400000 non-null  float64
#  12  GPS                   400000 non-null  object
#  13  Speed(km/hr)          400000 non-null  float64
# ...

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set(color_codes=True)

# %%
combined_data.isnull().sum()
# Out:
# VehicleID               0
# Timestamp               0
# Temperature             0
# Speed                   0
# EngineKnock             0
# CoolantTemp             0
# ThrottlePosition        0
# MAPSensor               0
# OxygenSensor            0
# RainSensor              0
# VoltageSensor           0
# CamshaftPosition        0
# GPS                     0
# Speed(km/hr)            0
# Acceleration            0
# MaintenanceType         0
# MaintenanceCategory     0
# MaintenanceFrequency    0
# MaintenanceSeverity     0
# MaintenanceDate         0
# MaintenanceCost(Ksh)    0
# MaintenanceInterval     0
# EventMileage            0
# dtype: int64

# %%
combined_data.nunique()
# Out:
# VehicleID               100000
# Timestamp                99839
# Temperature             100000
# Speed                   100000
# EngineKnock                 18
# CoolantTemp             100000
# ThrottlePosition        100000
# MAPSensor               100000
# OxygenSensor            100000
# RainSensor              100000
# VoltageSensor           100000
# CamshaftPosition        100000
# GPS                     100000
# Speed(km/hr)             86792
# Acceleration            100000
# MaintenanceType              4
# MaintenanceCategory          3
# MaintenanceFrequency         3
# MaintenanceSeverity          3
# MaintenanceDate         399998
# MaintenanceCost(Ksh)    385832
# MaintenanceInterval        364
# EventMileage            209038
# dtype: int64

# %%
combined_data.shape
# Out:
# (400000, 23)

# %%
combined_data.groupby('MaintenanceType').size()
# Out:
# MaintenanceType
# Air Filter Replacement    100000
# Brake Replacement         100000
# Oil Change                100000
# Tire Rotation             100000
# dtype: int64

# %%
combined_data.groupby('MaintenanceCategory').size()
# Out:
# MaintenanceCategory
# Repairs                100000
# Routine Maintenance    200000
# Schedules              100000
# dtype: int64

# %%
combined_data.duplicated().shape
# Out:
# (400000,)

# %%
cat_cols = combined_data.select_dtypes(include=['object']).columns
num_cols = combined_data.select_dtypes(include=np.number).columns.tolist()
print('Categorical Columns')
print(cat_cols)
print('Numerical Columns')
print(num_cols)
# Out:
# Categorical Columns
# Index(['Timestamp', 'GPS', 'MaintenanceType', 'MaintenanceCategory',
#        'MaintenanceFrequency', 'MaintenanceSeverity', 'MaintenanceDate',
#        'MaintenanceInterval'],
#       dtype='object')
# Numerical Columns
# ['VehicleID', 'Temperature', 'Speed', 'EngineKnock', 'CoolantTemp', 'ThrottlePosition', 'MAPSensor', 'OxygenSensor', 'RainSensor', 'VoltageSensor', 'CamshaftPosition', 'Speed(km/hr)', 'Acceleration', 'MaintenanceCost(Ksh)', 'EventMileage']

# %%
sns.boxplot(x = combined_data['Acceleration'])
# Out:
# <Axes: xlabel='Acceleration'>

# %%
sns.boxplot(x = combined_data['CamshaftPosition'])
# Out:
# <Axes: xlabel='CamshaftPosition'>

# %%
sns.boxplot(x = combined_data['CoolantTemp'])
# Out:
# <Axes: xlabel='CoolantTemp'>

# %%
sns.boxplot(x = combined_data['Temperature'])
# Out:
# <Axes: xlabel='Temperature'>

# %%
sns.boxplot(x = combined_data['EngineKnock'])
# Out:
# <Axes: xlabel='EngineKnock'>

# %%
sns.boxplot(x = combined_data['MAPSensor'])
# Out:
# <Axes: xlabel='MAPSensor'>

# %%
sns.boxplot(x = combined_data['Speed'])
# Out:
# <Axes: xlabel='Speed'>

# %%
sns.histplot(num_cols, bins=20, kde=True)
plt.title('Distribution of Numeric Columns')
plt.show()

# %%
for col in num_cols:
  print(col)
  print('Skew:', round(combined_data[col].skew(), 2))
  plt.figure(figsize = (15,4))
  plt.subplot(1, 2, 1)
  combined_data[col].hist(grid=False)
  plt.ylabel('count')
  plt.subplot(1, 2, 2)
  sns.boxplot(x = combined_data[col])
  plt.show()
# Out:
# VehicleID
# Skew: 0.0
# Temperature
# Skew: 0.01
# Speed
# Skew: 0.0
# EngineKnock
# Skew: 0.44
# CoolantTemp
# Skew: -0.0
# ThrottlePosition
# Skew: 0.0
# MAPSensor
# Skew: -0.0
# OxygenSensor
# Skew: -0.01
# RainSensor
# Skew: -0.0
# VoltageSensor
# Skew: 0.02
# CamshaftPosition
# Skew: 0.0
# Speed(km/hr)
# Skew: -2.19
# Acceleration
# Skew: 0.01
# MaintenanceCost(Ksh)
# Skew: -0.0
# EventMileage
# Skew: 0.38

# %%
fig, axes = plt.subplots(3, 2, figsize=(15, 8))
fig.suptitle('Bar plots for all the Categorical Variables')
sns.countplot(ax = axes[0,0], x='GPS', data=combined_data, color='blue',
              order=combined_data['GPS'].head(20).value_counts().index);

sns.countplot(ax = axes[0,1], x='MaintenanceType', data=combined_data, color='blue',
              order=combined_data['MaintenanceType'].head(20).value_counts().index);

sns.countplot(ax = axes[1,0], x='MaintenanceCategory', data=combined_data, color='blue',
              order=combined_data['MaintenanceCategory'].head(20).value_counts().index);

sns.countplot(ax = axes[1,1], x='MaintenanceFrequency', data=combined_data, color='blue',
              order=combined_data['MaintenanceFrequency'].head(20).value_counts().index);

sns.countplot(ax = axes[2,0], x='MaintenanceSeverity', data=combined_data, color='blue',
              order=combined_data['MaintenanceSeverity'].head(20).value_counts().index);

sns.countplot(ax = axes[2,1], x='MaintenanceDate', data=combined_data, color='blue',
              order=combined_data['MaintenanceDate'].head(20).value_counts().index);

sns.countplot(ax=axes[1, 1], x='MaintenanceInterval', data=combined_data, color='blue',
              order=combined_data['MaintenanceInterval'].head(20).value_counts().index);

axes[0,0].tick_params(labelrotation=90)
axes[0,1].tick_params(labelrotation=90)
axes[1,0].tick_params(labelrotation=90)
axes[1,1].tick_params(labelrotation=90)
axes[2,0].tick_params(labelrotation=90)
axes[2,1].tick_params(labelrotation=90)
axes[1,1].tick_params(labelrotation=90)

# %%
correlation_matrix = combined_data.corr()
sns.set_context("notebook", font_scale=1.0, rc={'lines.linewitdh': 2.5})
plt.figure(figsize=(13,7))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f")
plt.title('Correlation Matrix')
plt.show()
# Out:
# <ipython-input-48-2372b1654382>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = combined_data.corr()

# %%
combined_data.head(20)
# Out:
#     VehicleID            Timestamp  Temperature      Speed  EngineKnock  \
# 0           1  2023-07-01 07:21:28    91.843427  25.610070            5
# 1           1  2023-07-01 07:21:28    91.843427  25.610070            5
# 2           1  2023-07-01 07:21:28    91.843427  25.610070            5
# 3           1  2023-07-01 07:21:28    91.843427  25.610070            5
# 4           2  2023-02-27 18:48:36    87.583211  23.838311            4
# 5           2  2023-02-27 18:48:36    87.583211  23.838311            4
# 6           2  2023-02-27 18:48:36    87.583211  23.838311            4
# 7           2  2023-02-27 18:48:36    87.583211  23.838311            4
# 8           3  2023-10-23 13:51:59    89.652564  60.784985            2
# 9           3  2023-10-23 13:51:59    89.652564  60.784985            2
# 10          3  2023-10-23 13:51:59    89.652564  60.784985            2
# 11          3  2023-10-23 13:51:59    89.652564  60.784985            2
# ...

# %%
sns.pairplot(data=combined_data[['Acceleration', 'Speed', 'Temperature', 'CoolantTemp']], hue= 'Speed')

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import OneHotEncoder, StandardScaler

# %%
combined_data['Timestamp'] = pd.to_datetime(combined_data['Timestamp'])
combined_data['DayOfWeek'] = combined_data['Timestamp'].dt.dayofweek
combined_data['HourOfDay'] = combined_data['Timestamp'].dt.hour

# %%
combined_data.describe()
# Out:
#            VehicleID    Temperature          Speed    EngineKnock  \
# count  400000.000000  400000.000000  400000.000000  400000.000000
# mean    50000.500000      90.002591      44.974537       5.007410
# std     28867.549542       2.118191      14.429944       2.245335
# min         1.000000      80.271264      20.000278       0.000000
# 25%     25000.750000      88.566320      32.460476       3.000000
# 50%     50000.500000      90.001885      44.949592       5.000000
# 75%     75000.250000      91.430442      57.469594       6.000000
# max    100000.000000      99.215205      69.999917      17.000000
#
#          CoolantTemp  ThrottlePosition      MAPSensor   OxygenSensor  \
# count  400000.000000     400000.000000  400000.000000  400000.000000
# mean       89.998911         49.891848     100.022866       0.203134
# std         2.125706         28.911087      11.550234       2.004628
# min        80.102124          0.000852      80.000073      -8.619409
# ...

# %%
combined_data['Timestamp'] = pd.to_datetime(combined_data['Timestamp'])

# %%
duplicate_timestamps = combined_data[combined_data.duplicated(subset=['VehicleID', 'Timestamp'], keep=False)]
print(duplicate_timestamps)
# Out:
#         VehicleID           Timestamp  Temperature      Speed  EngineKnock  \
# 0               1 2023-07-01 07:21:28    91.843427  25.610070            5
# 1               1 2023-07-01 07:21:28    91.843427  25.610070            5
# 2               1 2023-07-01 07:21:28    91.843427  25.610070            5
# 3               1 2023-07-01 07:21:28    91.843427  25.610070            5
# 4               2 2023-02-27 18:48:36    87.583211  23.838311            4
# ...           ...                 ...          ...        ...          ...
# 399995      99999 2023-10-02 18:10:12    89.670646  35.996885            4
# 399996     100000 2023-07-21 05:09:15    88.624700  61.634277            0
# 399997     100000 2023-07-21 05:09:15    88.624700  61.634277            0
# 399998     100000 2023-07-21 05:09:15    88.624700  61.634277            0
# 399999     100000 2023-07-21 05:09:15    88.624700  61.634277            0
#
# ...

# %%
combined_data = combined_data.drop_duplicates(subset=['VehicleID', 'Timestamp'])

# %%
combined_data['Timestamp'] = pd.to_datetime(combined_data['Timestamp'])
# Out:
# <ipython-input-57-2c7c72f9b83b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined_data['Timestamp'] = pd.to_datetime(combined_data['Timestamp'])

# %%
combined_data.sort_values(['VehicleID', 'Timestamp'], inplace=True)
# Out:
# <ipython-input-59-aded0cc0f2b5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined_data.sort_values(['VehicleID', 'Timestamp'], inplace=True)

# %%
combined_data['RUL'] = combined_data.groupby('VehicleID')['Timestamp'].transform(lambda x: (x.max()-x).dt.days)
# Out:
# <ipython-input-67-73ecf4532b62>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined_data['RUL'] = combined_data.groupby('VehicleID')['Timestamp'].transform(lambda x: (x.max()-x).dt.days)

# %%
print(combined_data[['VehicleID', 'RUL']])
# Out:
#         VehicleID  RUL
# 0               1    0
# 4               2    0
# 8               3    0
# 12              4    0
# 16              5    0
# ...           ...  ...
# 399980      99996    0
# 399984      99997    0
# 399988      99998    0
# 399992      99999    0
# 399996     100000    0
#
# [100000 rows x 2 columns]
